# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
porter = PorterStemmer()
print(porter.stem("Playing"))
# Out:
# play

# %%
print(porter.stem("ran"))
# Out:
# ran

# %%
print(porter.stem("bosses"))
# Out:
# boss

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()   

sentence = "Lemmatization is more  sophisticated than stemming".split()

for token in sentence:
    stemmed_word = ps.stem(token)
    print(token, "-", stemmed_word)
    print()
# Out:
# Lemmatization - lemmat
#
# is - is
#
# more - more
#
# WALKBR - walkbr
#
# sophisticated - sophist
#
# than - than
#
# stemming - stem

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()   # Create an instance

sentence = "unnecessary bery".split()

for token in sentence:
    stemmed_word = ps.stem(token)
    print(token, "-", stemmed_word)
    print()
# Out:
# unnecessary - unnecessari
#
# bery - beri

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("walkes"))
# Out:
# walkes

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("walking"))
# Out:
# walking

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("walking", pos=wordnet.VERB))
# Out:
# walk

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("going", pos=wordnet.VERB))
# Out:
# go

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("ran", pos=wordnet.VERB))
# Out:
# run

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("mice"))
# Out:
# mouse

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("was", pos=wordnet.VERB))
# Out:
# be

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("was"))
# Out:
# wa

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("is", pos=wordnet.VERB))
# Out:
# be

# %%
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("better", pos=wordnet.ADJ))
# Out:
# good

# %%
nltk.download('averaged_perceptron_tagger_eng')
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
        sentence = "Donald Trump has a devoted following".split()

words_and_tags = nltk.pos_tag(sentence)
print(words_and_tags)

for word, tag in words_and_tags:
    wn_tag = get_wordnet_pos(tag)
    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    print(lemma, end=" ")

print()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\souad\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [('unnecessary', 'JJ'), ('bery', 'NN')]
# unnecessary bery

# %%
nltk.download('averaged_perceptron_tagger_eng')
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
        sentence = "Donald Trump has a devoted following".split()

words_and_tags = nltk.pos_tag(sentence)
print(words_and_tags)

for word, tag in words_and_tags:
    wn_tag = get_wordnet_pos(tag)
    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    print(lemma, end=" ")

print()
# Out:
# [('unnecessary', 'JJ'), ('bery', 'NN')]
# unnecessary bery
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\souad\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
sentence = "Donald Trump has a devoted following".split()

words_and_tags = nltk.pos_tag(sentence)
print(words_and_tags)

for word, tag in words_and_tags:
    wn_tag = get_wordnet_pos(tag)
    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    print(lemma, end=" ")

print()
# Out:
# [('Donald', 'NNP'), ('Trump', 'NNP'), ('has', 'VBZ'), ('a', 'DT'), ('devoted', 'VBN'), ('following', 'NN')]
# Donald Trump have a devote following

# %%
sentence = "The cat was following the bird as it flew by".split()

words_and_tags = nltk.pos_tag(sentence)

for word, tag in words_and_tags:
    wn_tag = get_wordnet_pos(tag)
    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    print(lemma, end=" ")

print()
# Out:
# The cat be follow the bird a it fly by
