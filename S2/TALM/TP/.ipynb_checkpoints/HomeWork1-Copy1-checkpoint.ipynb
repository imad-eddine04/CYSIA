# %%
with open("Algerian.txt", "w") as file:
    file.write("+213 6 77 12 34 56, mohamed.karim@gmail.com, +213 5 66 78 90 12, fatima.zed@yahoo.fr, +213 6 55 43 21 78, amine.belhadj@outlook.com, +213 5 44 33 22 11, karima.benali@protonmail.com, +213 6 88 99 00 11, yacine.berkani@gmail.com, +213 5 77 66 55 44, nadia.khelifi@icloud.com, +213 6 99 88 77 66, sofiane.meziane@company.dz, +213 5 22 33 44 55, lila.bouzid@univ-temouchent.edu.dz, +213 6 11 22 33 44, reda.bensalah@student.univ-temouchent.edu.dz, +213 5 33 44 55 66, selma.boudjema@univ-temouchent.edu.dz, +213 7 40 29 75 62, a.benhamouda@gmail.com, +213 7 58 22 43 91, n.khalfi@outlook.com, +213 7 65 11 34 78, r.boukhalfa@company.dz, +213 7 71 56 88 09, d.boumediene@univ-alger.dz, +213 7 62 47 21 30, m.khediri@yahoo.fr, +213 7 63 19 54 80, s.achour@protonmail.com")

# %%
with open("Algerian.txt", "r") as file: text = file.read()
print(text)
# Out:
# +213 6 55 23 41 98, ahmed.benali@gmail.com, +213 5 91 78 90 12, y.khelifi@yahoo.fr, +213 6 66 34 56 01, m.amrani@outlook.com, +213 5 83 11 88 73, lina.bouzid@protonmail.com, +213 6 70 45 22 19, sofiane.rahmani@gmail.com, +213 5 54 60 14 55, nour.elhouda@icloud.com, +213 6 91 02 67 44, k.zerrouki@company.dz, +213 5 88 73 09 26, samira.toumi@univ-temouchent.edu.dz, +213 6 64 98 31 07, bilal.messaoudi@student.univ-temouchent.edu.dz, +213 5 66 40 12 89, amel.boudjemaa@univ-temouchent.edu.dz

# %%
import re
#extract ooredoo numbers
mobilis_pattern = r"(\+213\s6\s\d{2}\s\d{2}\s\d{2}\s\d{2})"
mobilis_result = re.findall(mobilis_pattern, text)
if mobilis_result: 
    for i in mobilis_result:
        print("mobilis phone : ", i)
else: print("Mobilise phones Not Found!")
#extract ooredoo numbers
ooredoo_pattern = r"(\+213\s5\s\d{2}\s\d{2}\s\d{2}\s\d{2})"
ooredoo_result = re.findall(ooredoo_pattern, text)
if ooredoo_result: 
    for i in ooredoo_result:
        print("ooredoo phone : ", i)
else: print("ooredoo phones Not Found!")
# Out:
# Ther is 5 Mobilis Phones :
# mobilis phone :  +213 6 55 23 41 98
# mobilis phone :  +213 6 66 34 56 01
# mobilis phone :  +213 6 70 45 22 19
# mobilis phone :  +213 6 91 02 67 44
# mobilis phone :  +213 6 64 98 31 07
# Ther is 5 ooredoo Phones :
# ooredoo phone :  +213 5 91 78 90 12
# ooredoo phone :  +213 5 83 11 88 73
# ooredoo phone :  +213 5 54 60 14 55
# ooredoo phone :  +213 5 88 73 09 26
# ooredoo phone :  +213 5 66 40 12 89

# %%
#now for the emails from aintmouchen
tmouch_pattern = r"(\S+@univ-temouchent.edu.dz)"
tmouch_result = re.findall(tmouch_pattern, text)
if tmouch_result: 
    for i in tmouch_result:
        print("tmouchent mails : ", i)
else: print("tmouchent mails Not Found!")
