# %%
with open("sample.txt","w") as file:
    file.write("tayeb benyahia souad  30/09/2003  0666666666 souad.tayebbenyahia@univ.temouchent.edu.dz")

# %%
with open("sample.txt","r") as file:
    text = file.read()
    print(text)
# Out:
# tayeb benyahia souad 30/09/2003 0666666666 souad.tayebbenyahia@univ.temouchent.edu.dz

# %%
tokens = text.split()
print(tokens)
# Out:
# ['tayeb', 'benyahia', 'souad', '30/09/2003', '06666666666', 'souad.tayebbenyahia@univ.temouchent.edu.dz']

# %%
import re
simple_text = "le chat dort sur le tapis"
simple_pattern =r"chat"
result = re.search(simple_pattern , simple_text)
print(result.group())
# Out:
# chat

# %%
email_pattern = r"(\S+@\S+\.\S+)"
email_result = re.search(email_pattern,text)
if email_result:
    print("Email:",email_result.group(1))
else:
    print("no email found")
# Out:
# Email: souad.tayebbenyahia@univ.temouchent.edu.dz

# %%
tel_pattern = r"\b\d{10}\b"
tel_result = re.search(tel_pattern,text)
if tel_result:
    print ("Telephone",tel_result.group())
else:
    print("no telephone found")
# Out:
# Telephone 0666666666

# %%
date_pattern = r"DD/MM/YYY"
date_result = re.search(date_pattern,text)
if date_result:
    print("Birth Date:",date_result.group())
else:
    print("no birth date found")
# Out:
# no birth date found

# %%
# Create sample file algerian.txt with example data
with open("algerian.txt", "w") as file:
    file.write("""tayeb benyahia souad 30/09/2003 06666666666 souad.tayebbenyahia@univ-temouchent.edu.dz
0612345678 some.email@example.com
0751234567 mobilis.user@random.com
0569876543 ooredoo.user@gmail.com
0712345678 valid.mobilis@univ-temouchent.edu.dz
0512345678 valid.ooredoo@univ-temouchent.edu.dz
""")
print("File 'algerian.txt' created with sample data.")
# Out:
# File 'algerian.txt' created with sample data.

# %%
import re

# Define regex patterns
phone_pattern = r"\b(07\d{8}|05\d{8})\b"  
# Explanation: 
# \b = word boundary
# 07 or 05 followed by exactly 8 digits (Algerian mobile format)
# so total length: 10 digits

email_pattern = r"\b[\w\.-]+@univ-temouchent\.edu\.dz\b"
# Explanation:
# word characters, dots or hyphens before '@'
# domain: @univ-temouchent.edu.dz

# %%
# Read file
with open("algerian.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# tayeb benyahia souad 30/09/2003 06666666666 souad.tayebbenyahia@univ-temouchent.edu.dz
# 0612345678 some.email@example.com
# 0751234567 mobilis.user@random.com
# 0569876543 ooredoo.user@gmail.com
# 0712345678 valid.mobilis@univ-temouchent.edu.dz
# 0512345678 valid.ooredoo@univ-temouchent.edu.dz
